# %%
# Performance loader creates multiple requests with multiple file

# %%
import requests


def get_token():

    url = "http://localhost:8000/api/login/"

    body = {
        'email': 'admin@email.mn',
        'password': 'secure_password'
    }

    response = requests.post(url, data=body)
    access_token = response.json()['access']

    return access_token

# %%
access_token = get_token()

# %%
import os
import magic
import requests

BASE_DIR = 'D:\\Projects\\pdf-statement-parser\\huulga_pdfs\\'

def upload_khanbank_statement(token, call_count = 1):
    url = 'http://localhost:8000/api/transactions/statement_upload/'
    
    headers = {
        'Authorization': f'Bearer {token}'
    }

    file_names = [
        '01-regular-ЦЭВЭЭНДОРЖ ЭНХТУЯА ХААН БАНК 2.pdf',
        '01-regular-ЦЭВЭЭНДОРЖ ЭНХТУЯА ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 1.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 2.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 4.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 1.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 1.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 1.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 2.pdf',
        '01-regular-НАРАНЖАРГАЛ ЧИНБАТ ХААН БАНК.pdf',
        '01-regular-НАРАНЖАРГАЛ ЧИНБАТ ХААН БАНК 2.pdf',
        '01-regular-ЦЭВЭЭНДОРЖ ЭНХТУЯА ХААН БАНК 1.pdf',
        '01-regular-ЦЭВЭЭНДОРЖ ЭНХТУЯА ХААН БАНК 2.pdf',
        '01-regular-ЦЭВЭЭНДОРЖ ЭНХТУЯА ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 1.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 2.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 4.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 1.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 1.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 1.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 2.pdf',
        '01-regular-НАРАНЖАРГАЛ ЧИНБАТ ХААН БАНК.pdf',
        '01-regular-НАРАНЖАРГАЛ ЧИНБАТ ХААН БАНК 2.pdf',
        '01-regular-ЦЭВЭЭНДОРЖ ЭНХТУЯА ХААН БАНК 1.pdf',
        '01-regular-ЦЭВЭЭНДОРЖ ЭНХТУЯА ХААН БАНК 2.pdf',
        '01-regular-ЦЭВЭЭНДОРЖ ЭНХТУЯА ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 1.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 2.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 3.pdf',
        '01-regular-ДОРЛИГЖАВ ГАНХУЯГ ХААН БАНК 4.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 1.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 1.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 1.pdf',
        '01-regular-НАРАНЖАРГАЛ БАТЖАРГАЛ ХААН БАНК 2.pdf',
        '01-regular-НАРАНЖАРГАЛ ЧИНБАТ ХААН БАНК.pdf',
        '01-regular-НАРАНЖАРГАЛ ЧИНБАТ ХААН БАНК 2.pdf',
        '01-regular-ЦЭВЭЭНДОРЖ ЭНХТУЯА ХААН БАНК 1.pdf',
    ]

    for val in range(0, call_count):
        files = []  # rebuild per call to avoid reusing closed handles

        for file in file_names:
            file_path = os.path.join(BASE_DIR, file)

            if not os.path.exists(file_path):
                raise FileNotFoundError(f"File not found: {file}")

            f = open(file_path, "rb")
            file_type = magic.from_buffer(f.read(2048), mime=True)
            f.seek(0)
            files.append(("files", (file, f, file_type)))

        print("called: ", val + 1)
        response = requests.post(url, headers=headers, files=files)
        try:
            print(response.json())
        except Exception:
            print(response.text)
        finally:
            # close all opened file handles and drop references
            for _, (_, f, _) in files:
                try:
                    f.close()
                except Exception:
                    pass
            files = []

upload_khanbank_statement(access_token, 6)
# Out:
# called:  1
# ...
